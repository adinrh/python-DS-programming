# %% [markdown]
# # Graph Taversal
#
# Graph doesn't have root nodes: Node/vertex and adjacent node. \
# At its edge, it can carry a value.

# %%
class Node():
    def __init__(self, value):
        self.value = value
        self.adjecent_list =[]
        self.visited = False

class Graph():
    pass

# %%
node1 =
